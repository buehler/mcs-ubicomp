# %% [markdown]
# Install Dependencies

# %%
# !pip install rocketlogger
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: rocketlogger in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (2.1.2)
# Requirement already satisfied: numpy<1.26,>=1.13 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from rocketlogger) (1.25.2)
# Requirement already satisfied: pandas in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/christophalexander.buehler/Development/mcs-ubicomp/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# Import dependencies and load data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import os
from numpy import linalg as LA
from rocketlogger.data import RocketLoggerData

# %%
# # Configuration
# Export figure settings
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['ps.useafm'] = True

# constants
LPM_CURRENT_THRESHOLD = 150e-6 # ampere
TRIM_START = 1.0 # seconds
TRIM_END = 1.0 # seconds
    
# input folder
input_folder = os.path.join('./')

# input files -- update path 
measurement_file = 'data/Onboard-data.rld'
# measurement_file = 'data/Offboard-data.rld'

# Load data
data = RocketLoggerData(os.path.join(input_folder, measurement_file))
data = data.merge_channels(True)
data_sample_rate = int(data._header['sample_rate'])
data_comment = data.get_comment()

# %%
# RAW DATA
I_app = data.get_data('I1').squeeze()[int(TRIM_START*data_sample_rate):-int(TRIM_END*data_sample_rate)]
V_app = data.get_data('V1').squeeze()[int(TRIM_START*data_sample_rate):-int(TRIM_END*data_sample_rate)]
app_active_window = data.get_data('DI1').squeeze()[int(TRIM_START*data_sample_rate):-int(TRIM_END*data_sample_rate)] > 0

print("Average supply voltage:  {:1.8f} mA ".format(1000*np.mean(I_app)))
# Out:
# Average supply voltage:  0.78844591 mA

# %% [markdown]
# Extract application states

# %%
# TIME
t_app = data.get_time()[int(TRIM_START*data_sample_rate):-int(TRIM_END*data_sample_rate)]
t_app = t_app - t_app[0]
dt_app = np.hstack([np.diff(t_app), 0])

# POWER 
P_app = 1 * V_app * I_app

# Determine the start and end of task based on the digital signal
app_start = np.diff(np.hstack([[0], app_active_window])) > 0
app_start_index = np.nonzero(app_start)[0]
num_start = len(app_start_index)
# extract the end of button press
app_end = np.diff(np.hstack([[0], app_active_window])) < 0
app_end_index = np.nonzero(app_end)[0]
num_end = len(app_end_index)

print('Num. start signals recognized: ', num_start)
print('Num. stop signals recognized: ', num_end)
# Out:
# Num. start signals recognized:  73
# Num. stop signals recognized:  73

# %%
# plot the power trace and the calculated app state
fig, ax1 = plt.subplots()
lns1 = ax1.plot(t_app,P_app, label='Power Trace', color="blue")
plt.xlabel('time [s]')
plt.ylabel('Power [W]')
plt.ylim(0,0.08)
# second y axis
ax2 = ax1.twinx()
lns2 = ax2.plot(t_app,app_active_window, label='App state', color="orange")
ax2.set_ylim(0,1.5)
ax2.set_ylabel('State')
ax2.set_yticks([0, 1])
ax2.set_yticklabels( ["sleep", "active task"])
# add legends for both lines
lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs)
plt.tight_layout()
plt.savefig(measurement_file+"power_overview.png", bbox_inches="tight")

# # Plot the app start and app end 
# plt.figure()
# plt.plot(t_app,app_start, label='Start')
# plt.plot(t_app,app_end, label='End')
# plt.xlabel('time [s]')
# plt.ylabel('State')
# plt.yticks([0, 1], ["sleep", "active task"])
# plt.legend()
# plt.tight_layout()
# plt.savefig("state_overview.png", bbox_inches="tight")

# Print one activation  in detail
detail_range = range(190734,192092) # To be used with onboard file
# detail_range = range(193734,195092)
plt.figure()
_ = plt.plot(1e3 * (t_app[detail_range] - t_app[detail_range].min()), 1e3 * P_app[detail_range], label='Power Trace') 
_ = plt.plot(1e3 * (t_app[detail_range] - t_app[detail_range].min()), 20 * app_start[detail_range], label='Power Trace') 
_ = plt.plot(1e3 * (t_app[detail_range] - t_app[detail_range].min()), 20 * app_end[detail_range], label='Power Trace') 
_ = plt.xlabel('time [ms]')
_ = plt.ylabel('power [mW]')
plt.tight_layout()
plt.savefig(measurement_file+"closeup.png", bbox_inches="tight")
plt.show()

# %%
# calculate app active windows
app_active = np.zeros_like(app_start, dtype=bool)
app_active_index = np.zeros([num_start, 2], dtype=int)

for t in range(num_start):
    idx_start = app_start_index[t]
    idx_end = app_end_index[t]

    print("{}th Active time: {:1.4f} s".format(t+1, t_app[idx_end]-t_app[idx_start]))
# Out:
# 1th Active time: 0.0051 s
# 2th Active time: 0.0053 s
# 3th Active time: 0.0051 s
# 4th Active time: 0.0053 s
# 5th Active time: 0.0053 s
# 6th Active time: 0.0053 s
# 7th Active time: 0.0051 s
# 8th Active time: 0.0053 s
# 9th Active time: 0.0051 s
# 10th Active time: 0.0051 s
# 11th Active time: 0.0051 s
# 12th Active time: 0.0051 s
# 13th Active time: 0.0053 s
# 14th Active time: 0.0053 s
# 15th Active time: 0.0053 s
# 16th Active time: 0.0053 s
# 17th Active time: 0.0053 s
# 18th Active time: 0.0053 s
# 19th Active time: 0.0053 s
# 20th Active time: 0.0053 s
# 21th Active time: 0.0053 s
# 22th Active time: 0.0053 s
# 23th Active time: 0.0051 s
# 24th Active time: 0.0053 s
# 25th Active time: 0.0053 s
# 26th Active time: 0.0051 s
# 27th Active time: 0.0053 s
# 28th Active time: 0.0053 s
# 29th Active time: 0.0053 s
# 30th Active time: 0.0053 s
# 31th Active time: 0.0053 s
# 32th Active time: 0.0053 s
# 33th Active time: 0.0053 s
# 34th Active time: 0.0051 s
# 35th Active time: 0.0053 s
# 36th Active time: 0.0051 s
# 37th Active time: 0.0053 s
# 38th Active time: 0.0053 s
# 39th Active time: 0.0051 s
# 40th Active time: 0.0053 s
# 41th Active time: 0.0053 s
# 42th Active time: 0.0053 s
# 43th Active time: 0.0053 s
# 44th Active time: 0.0053 s
# 45th Active time: 0.0053 s
# 46th Active time: 0.0053 s
# 47th Active time: 0.0053 s
# 48th Active time: 0.0053 s
# 49th Active time: 0.0053 s
# 50th Active time: 0.0053 s
# 51th Active time: 0.0053 s
# 52th Active time: 0.0051 s
# 53th Active time: 0.0053 s
# 54th Active time: 0.0053 s
# 55th Active time: 0.0053 s
# 56th Active time: 0.0053 s
# 57th Active time: 0.0053 s
# 58th Active time: 0.0053 s
# 59th Active time: 0.0054 s
# 60th Active time: 0.0051 s
# 61th Active time: 0.0053 s
# 62th Active time: 0.0053 s
# 63th Active time: 0.0053 s
# 64th Active time: 0.0053 s
# 65th Active time: 0.0051 s
# 66th Active time: 0.0053 s
# 67th Active time: 0.0053 s
# 68th Active time: 0.0053 s
# 69th Active time: 0.0051 s
# 70th Active time: 0.0053 s
# 71th Active time: 0.0053 s
# 72th Active time: 0.0053 s
# 73th Active time: 0.0053 s

# %% [markdown]
# Energy and time statistics

# %%
# TODO: Calculate the energy consumed by each task
js = []
for t in range(num_start):
    s = app_start_index[t]
    e = app_end_index[t]
    p_activation = P_app[e] - P_app[s]
    t_activation = t_app[e] - t_app[s]
    j_act = p_activation * t_activation
    j = np.absolute(j_act)
    js.append(j)

    print(f"{t+1}th Activation used: {j} Joules of power and was done in {t_activation} s")
print(f"The average was: {sum(js) / len(js)} Joules")
# Out:
# 1th Activation used: 7.468265911589277e-07 Joules of power and was done in 0.005143040000000099 s
# 2th Activation used: 8.214763261369617e-08 Joules of power and was done in 0.005268479999999798 s
# 3th Activation used: 9.701016220219752e-07 Joules of power and was done in 0.005143040000000099 s
# 4th Activation used: 3.6659909094083136e-07 Joules of power and was done in 0.005268479999999798 s
# 5th Activation used: 7.899037860644217e-08 Joules of power and was done in 0.005268479999999798 s
# 6th Activation used: 4.1798100523862176e-07 Joules of power and was done in 0.005268479999998021 s
# 7th Activation used: 6.735977894239651e-07 Joules of power and was done in 0.005143040000000099 s
# 8th Activation used: 1.1687200044973357e-06 Joules of power and was done in 0.005268480000005127 s
# 9th Activation used: 5.614968785383599e-07 Joules of power and was done in 0.005143040000000099 s
# 10th Activation used: 2.298136599481413e-06 Joules of power and was done in 0.005143040000000099 s
# 11th Activation used: 2.1929647705583823e-07 Joules of power and was done in 0.005143040000000099 s
# 12th Activation used: 2.503083743717432e-07 Joules of power and was done in 0.005143040000000099 s
# 13th Activation used: 7.807384521541966e-07 Joules of power and was done in 0.005268479999998021 s
# 14th Activation used: 7.086666825859911e-07 Joules of power and was done in 0.005268480000005127 s
# 15th Activation used: 3.663446202897896e-07 Joules of power and was done in 0.005268480000005127 s
# 16th Activation used: 6.028715495340938e-07 Joules of power and was done in 0.005268479999998021 s
# 17th Activation used: 1.0159229888530651e-06 Joules of power and was done in 0.005268479999998021 s
# 18th Activation used: 1.0871022284775489e-06 Joules of power and was done in 0.005268480000005127 s
# 19th Activation used: 1.6575840694053822e-07 Joules of power and was done in 0.005268479999998021 s
# 20th Activation used: 1.9856398596770648e-07 Joules of power and was done in 0.005268479999998021 s
# 21th Activation used: 1.4757777043319267e-06 Joules of power and was done in 0.005268480000005127 s
# 22th Activation used: 4.6828285181689925e-07 Joules of power and was done in 0.005268479999998021 s
# 23th Activation used: 1.7609670335851531e-06 Joules of power and was done in 0.005143040000000099 s
# 24th Activation used: 3.5036542207437255e-08 Joules of power and was done in 0.005268479999998021 s
# 25th Activation used: 6.349803745828331e-07 Joules of power and was done in 0.005268479999998021 s
# 26th Activation used: 1.2550506699526198e-06 Joules of power and was done in 0.005143040000000099 s
# 27th Activation used: 9.863055078945286e-07 Joules of power and was done in 0.005268479999998021 s
# 28th Activation used: 2.4172902922619714e-07 Joules of power and was done in 0.005268480000005127 s
# 29th Activation used: 5.881484186054196e-07 Joules of power and was done in 0.005268479999998021 s
# 30th Activation used: 8.322511483838755e-07 Joules of power and was done in 0.005268479999998021 s
# 31th Activation used: 2.4699473200279988e-08 Joules of power and was done in 0.005268479999998021 s
# 32th Activation used: 3.008085861000141e-07 Joules of power and was done in 0.005268479999998021 s
# 33th Activation used: 7.875261501329154e-07 Joules of power and was done in 0.005268479999998021 s
# 34th Activation used: 5.321277701616931e-07 Joules of power and was done in 0.005143040000000099 s
# 35th Activation used: 1.1788068247370142e-06 Joules of power and was done in 0.005268479999998021 s
# 36th Activation used: 7.488033558702334e-08 Joules of power and was done in 0.005143039999992993 s
# 37th Activation used: 6.877868640562829e-07 Joules of power and was done in 0.005268479999998021 s
# 38th Activation used: 1.172659685512256e-06 Joules of power and was done in 0.005268479999998021 s
# 39th Activation used: 5.090868944956745e-07 Joules of power and was done in 0.005143040000007204 s
# 40th Activation used: 2.978191479097575e-07 Joules of power and was done in 0.005268479999998021 s
# 41th Activation used: 1.6778001458333524e-06 Joules of power and was done in 0.005268479999998021 s
# 42th Activation used: 1.2608220953011285e-06 Joules of power and was done in 0.005268479999998021 s
# 43th Activation used: 5.658600375386938e-07 Joules of power and was done in 0.005268479999998021 s
# 44th Activation used: 3.152653792710589e-07 Joules of power and was done in 0.005268479999998021 s
# 45th Activation used: 1.3527163328446253e-07 Joules of power and was done in 0.005268479999998021 s
# 46th Activation used: 1.1785685324950308e-06 Joules of power and was done in 0.005268480000012232 s
# 47th Activation used: 4.250881851318401e-07 Joules of power and was done in 0.005268479999998021 s
# 48th Activation used: 1.2470606691435082e-06 Joules of power and was done in 0.005268479999998021 s
# 49th Activation used: 2.967962530001946e-07 Joules of power and was done in 0.005268479999998021 s
# 50th Activation used: 5.355624389245959e-07 Joules of power and was done in 0.005268479999998021 s
# 51th Activation used: 1.2182390677107402e-06 Joules of power and was done in 0.005268479999998021 s
# 52th Activation used: 8.547846316054147e-10 Joules of power and was done in 0.005143040000007204 s
# 53th Activation used: 1.1270835973586692e-06 Joules of power and was done in 0.005268479999998021 s
# 54th Activation used: 2.216271316977843e-05 Joules of power and was done in 0.005268479999998021 s
# 55th Activation used: 5.383533234513211e-07 Joules of power and was done in 0.005268479999998021 s
# 56th Activation used: 1.177245329046848e-06 Joules of power and was done in 0.005268479999998021 s
# 57th Activation used: 6.681579042624581e-07 Joules of power and was done in 0.005268479999998021 s
# 58th Activation used: 1.221774366298285e-06 Joules of power and was done in 0.005268479999998021 s
# 59th Activation used: 8.623655592752601e-05 Joules of power and was done in 0.00539392000000305 s
# 60th Activation used: 7.667629798315024e-08 Joules of power and was done in 0.005143039999992993 s
# 61th Activation used: 4.798499252516135e-08 Joules of power and was done in 0.005268479999998021 s
# 62th Activation used: 1.6678312130906475e-06 Joules of power and was done in 0.005268479999998021 s
# 63th Activation used: 1.0510186374571232e-07 Joules of power and was done in 0.005268479999998021 s
# 64th Activation used: 4.931800422617706e-07 Joules of power and was done in 0.005268479999998021 s
# 65th Activation used: 1.3404762771488975e-07 Joules of power and was done in 0.005143040000007204 s
# 66th Activation used: 2.3487601386930736e-07 Joules of power and was done in 0.005268479999998021 s
# 67th Activation used: 1.3453520746716987e-06 Joules of power and was done in 0.005268479999998021 s
# 68th Activation used: 6.70037065781318e-08 Joules of power and was done in 0.005268479999998021 s
# 69th Activation used: 1.1355179834777243e-06 Joules of power and was done in 0.005143040000007204 s
# 70th Activation used: 8.90257485788562e-09 Joules of power and was done in 0.005268479999998021 s
# 71th Activation used: 6.768218334306332e-07 Joules of power and was done in 0.005268479999998021 s
# 72th Activation used: 5.460980017049389e-07 Joules of power and was done in 0.005268479999998021 s
# 73th Activation used: 1.3402439848207707e-06 Joules of power and was done in 0.0052684799999838106 s
# The average was: 2.143474156465103e-06 Joules
